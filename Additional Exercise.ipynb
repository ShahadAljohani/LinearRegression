# %%
# %%time
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from linreg import LinearModel
# Out:
# CPU times: user 747 ms, sys: 378 ms, total: 1.12 s
# Wall time: 1.16 s

# %%
#Relation between ambient temperatue of the room and the number of chirps
#Explicitly specified the xlrd engine
df = pd.read_excel('chirps.xls', engine='xlrd')
df.head()
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#            X          Y
# 0  20.000000  88.599998
# 1  16.000000  71.599998
# 2  19.799999  93.300003
# 3  18.400000  84.300003
# 4  17.100000  80.599998

# %%
x = df.X.values
y = df.Y.values
x = np.reshape(x, (x.shape[0], 1))
y = np.reshape(y, (y.shape[0], 1))

# %%
model = LinearModel(1)

losses = model.train(
    x, y,
    200, 0.0001
)
# Out:
# Iter: 0, Current loss: 1448.6223
# Iter: 20, Current loss: 469.6170
# Iter: 40, Current loss: 156.5777
# Iter: 60, Current loss: 56.4826
# Iter: 80, Current loss: 24.4768
# Iter: 100, Current loss: 14.2428
# Iter: 120, Current loss: 10.9704
# Iter: 140, Current loss: 9.9240
# Iter: 160, Current loss: 9.5893
# Iter: 180, Current loss: 9.4822

# %%
plt.plot(losses);

# %%
y_preds = model.forward_pass(x)

# %%
plt.plot(y, y_preds, 'r.');

# %%
print(model.W, model.b)
